# %%
import ghostscript

# %%
import tkinter

# %%
import camelot

# %%
import pandas as pd

# %%
tables=[0,1]

for i in range(2,18):
    tables.append(camelot.read_pdf(str(i)+'.pdf', pages="all")) # reading  pdf as csv
                                                            # tables objects are tables[0],tables[1],tables[2]......,tables[15]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d0b2c032ca48> in <module>()
#       2
#       3 for i in range(2,18):
# ----> 4     tables.append(camelot.read_pdf(str(j)+'.pdf', pages="all")) # reading  pdf as csv
#       5                                                             # tables objects are tables[0],tables[1],tables[2]......,tables[15]
#       6
#
# NameError: name 'j' is not defined

# %%
for i in range(2,17):
    tables[i][4].df.drop(0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-86-b0fe79854498> in <module>()
#       1 for i in range(2,17):
# ----> 2     tables[i][4].df.drop(0,inplace=True)
#
# D:\ARNAB\Anaconda_installed\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# D:\ARNAB\Anaconda_installed\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# D:\ARNAB\Anaconda_installed\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# D:\ARNAB\Anaconda_installed\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5015         if mask.any():
#    5016             if errors != "ignore":
# -> 5017                 raise KeyError(f"{labels[mask]} not found in axis")
#    5018             indexer = indexer[~mask]
#    5019         return self.delete(indexer)
#
# KeyError: '[0] not found in axis'

# %% [markdown]
# # upto this point the code blocks runs once, but the below blocks run multiple times

# %%
tables[6][4].df
# Out:
#               0      1       2          3  \
# 1       Village  Owned  Rented  Any Other
# 2   Math Binkar    123       1          4
# 3          Kaya    758       1         15
# 4  Chumarigacha    975       0          5
# 5      Tarakpur   1728       3          6
# 6    Bairgachhi   2020       9        164
# 7       Mankara    333       0         88
# 8  Chaltia (CT)   5625     263        233
# 9         Total  11562     277        515
#
#                                           4  \
# 1  Total \nunirrigated land\n (in hectares)
# 2                                      0.00
# 3                                     73.45
# 4                                     10.98
# 5                                    241.89
# 6                                      8.27
# 7                                    248.09
# 8                                    888.62
# 9                                   1471.30
#
#                                         5  \
# 1  Total \nirrigated land \n(in hectares)
# 2                                   10.78
# 3                                  117.06
# 4                                  364.58
# 5                                  219.44
# 6                                  165.92
# 7                                  160.61
# 8                               202906.61
# 9                               203945.00
#
#                                               6                      7  \
# 1  Total other \nirrigated land (in \nhectares)  Less than \nRs. 5,000
# 2                                          0.32                     76
# 3                                         12.55                    702
# 4                                          7.42                    767
# 5                                         10.06                   1273
# 6                                         11.30                   1475
# 7                                          2.31                    349
# 8                                        776.40                   2701
# 9                                        820.36                   7343
#
#                                        8                       9
# 1  Between \nRs. 5,000 \nand\n Rs 10,000  Rs. \n10,000 \nor more
# 2                                     44                       8
# 3                                     49                      23
# 4                                    157                      56
# 5                                    399                      70
# 6                                    523                     195
# 7                                     64                       8
# 8                                   1619                    1801
# 9                                   2855                    2161

# %%
s=pd.Series([0,1,2,3,4,5,6,7,8])
tables[6][4].df=tables[6][4].df.set_index(s)        # restructing the table number 4
tables[6][4].df
# Out:
#               0      1       2          3  \
# 0       Village  Owned  Rented  Any Other
# 1   Math Binkar    123       1          4
# 2          Kaya    758       1         15
# 3  Chumarigacha    975       0          5
# 4      Tarakpur   1728       3          6
# 5    Bairgachhi   2020       9        164
# 6       Mankara    333       0         88
# 7  Chaltia (CT)   5625     263        233
# 8         Total  11562     277        515
#
#                                           4  \
# 0  Total \nunirrigated land\n (in hectares)
# 1                                      0.00
# 2                                     73.45
# 3                                     10.98
# 4                                    241.89
# 5                                      8.27
# 6                                    248.09
# 7                                    888.62
# 8                                   1471.30
#
#                                         5  \
# 0  Total \nirrigated land \n(in hectares)
# 1                                   10.78
# 2                                  117.06
# 3                                  364.58
# 4                                  219.44
# 5                                  165.92
# 6                                  160.61
# 7                               202906.61
# 8                               203945.00
#
#                                               6                      7  \
# 0  Total other \nirrigated land (in \nhectares)  Less than \nRs. 5,000
# 1                                          0.32                     76
# 2                                         12.55                    702
# 3                                          7.42                    767
# 4                                         10.06                   1273
# 5                                         11.30                   1475
# 6                                          2.31                    349
# 7                                        776.40                   2701
# 8                                        820.36                   7343
#
#                                        8                       9
# 0  Between \nRs. 5,000 \nand\n Rs 10,000  Rs. \n10,000 \nor more
# 1                                     44                       8
# 2                                     49                      23
# 3                                    157                      56
# 4                                    399                      70
# 5                                    523                     195
# 6                                     64                       8
# 7                                   1619                    1801
# 8                                   2855                    2161

# %%
for i in range(1,11):
    tables[6][i].df.drop(0,axis=1,inplace=True)  # change tables[this value should be changed][]

# %%
frames=[]
for i in range(0,11):
    frames.append(tables[6][i].df)  # change tables[this value should be changed][]

# %%
result=pd.concat(frames,axis=1, ignore_index=True)

# %%
#import re
#import io
#import pandas as pd
import numpy as np

#with open('merged1.csv','r') as f:
 #   data = f.read()
#df = pd.read_csv(io.StringIO(re.sub('"\s*\n','"',data)))
df=result
for col in df.columns: #To replace all line breaks in all textual columns
    if df[col].dtype == np.object_:
        df[col] = df[col].str.replace('\n','');

# %%
df
# Out:
#              0          1                2                   3   \
# 0       Village  Sex Ratio  Total Household  Excluded Household
# 1   Math Binkar        991              128                  26
# 2          Kaya        939              774                  93
# 3  Chumarigacha        927              980                 133
# 4      Tarakpur        943             1742                 268
# 5    Bairgachhi        934             2193                 430
# 6       Mankara        874              421                  53
# 7  Chaltia (CT)        955             6121                2970
# 8         Total        943            12359                3973
# 9           NaN        NaN              NaN                 NaN
#
#                    4                   5                        6   \
# 0  Included household  Deprived Household  Zero Deprived Household
# 1                   3                  63                       36
# 2                   5                 514                      162
# 3                   1                 690                      156
# 4                  26                1165                      283
# 5                  26                1562                      175
# 6                   2                 301                       65
# 7                  37                2620                      494
# 8                 100                6915                     1371
# 9                 NaN                 NaN                      NaN
#
#                      7                                                  8   \
# 0  Household Owing Land  Households with any member earning more than R...
# 1                    22                                                  8
# 2                   104                                                 23
# 3                   383                                                 56
# 4                   342                                                 70
# 5                   173                                                195
# 6                    46                                                  8
# 7                   650                                               1801
# 8                  1720                                               2161
# 9                   NaN                                                NaN
#
#                                                   9   ...     69         70  \
# 0  Households with three or more rooms with pucca...  ...  Other  In Seeing
# 1                                                 12  ...      0          2
# 2                                                 52  ...      0          2
# 3                                                 98  ...      1          6
# 4                                                143  ...     11         16
# 5                                                245  ...      7         44
# 6                                                 27  ...      0          1
# 7                                               1773  ...    311         27
# 8                                               2350  ...    330         98
# 9                                                NaN  ...    NaN        NaN
#
#            71         72           73                  74              75  \
# 0  In Hearing  In Speech  In Movement  Mental Retardation  Mental Illness
# 1           0          2            1                   0               4
# 2           4          4           12                   6               0
# 3           5         11           17                  11               3
# 4          12         18           30                   7               8
# 5          11          8           43                   9              23
# 6           0          3            5                   1               6
# 7          10         17           72                  14              33
# 8          42         63          180                  48              77
# 9         NaN        NaN          NaN                 NaN             NaN
#
#                  76                   77             78
# 0  Other Disability  Multipls Disability  No Disability
# 1                 2                    1            446
# 2                 8                    0           3155
# 3                 9                    2           4659
# 4                11                   17           7573
# 5                17                   18           9171
# 6                11                    3           1876
# 7                22                   36          24851
# 8                80                   77          51731
# 9               NaN                  NaN            NaN
#
# [10 rows x 79 columns]

# %%
x=(df.columns)   # x = old column heading # it also runs once

# %%
y=list(df.iloc[0])   # actual column headings # it also runs once only

# %%
d = dict(zip(x,y))                # coping column names into pandas column name and deleting the duplcate column name
df_new = df.rename(columns=d)
df_new.drop(0,inplace=True)

# %%
df_new.to_csv("7.csv",index=False)
